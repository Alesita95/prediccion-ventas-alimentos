# %% [markdown]
# <a href="https://colab.research.google.com/github/Alesita95/Prediccion-Ventas-Alimentos/blob/main/Visualizaci%C3%B3n_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data = '/content/drive/MyDrive/BOOTCAMP_CODING_DOJO/PRACTICANDO_PLATAFORMA/Data.xlsx'
df = pd.read_excel(data)
df.head()
# Out:
#         Sport  2017  2013  2008  2007  2006  2005  2004
# 0    Football    37    39    41    43    43    34    37
# 1  Basketball    11    12     9    11    12    12    13
# 2    Baseball     9    14    10    13    11    12    10
# 3      Soccer     7     4     3     2     2     3     2
# 4  Ice hockey     4     3     4     4     2     4     3

# %%
df
# Out:
#                  Sport  2017  2013  2008  2007  2006  2005  2004
# 0             Football    37    39    41    43    43    34    37
# 1           Basketball    11    12     9    11    12    12    13
# 2             Baseball     9    14    10    13    11    12    10
# 3               Soccer     7     4     3     2     2     3     2
# 4           Ice hockey     4     3     4     4     2     4     3
# 5          Auto racing     2     2     3     3     4     5     5
# 6               Tennis     2     3     1     1     1     3     2
# 7                 Golf     1     2     2     2     3     2     2
# 8           Volleyball     1     0     1     0     0     1     0
# 9               Boxing     1     1     2     1     2     1     1
# 10          Gymnastics     1     0     1     1     1     0     1
# 11           Motocross     1     0     0     0     0     0     1
# 12  Ice/Figure skating     1     1     1     2     3     3     4
# ...

# %%
df.shape
# Out:
# (22, 8)

# %% [markdown]
# # Ordenando Datos

# %%
df_1 = df.melt(id_vars=['Sport'], var_name='Año', value_name='Participantes')
df_1
# Out:
#           Sport   Año  Participantes
# 0      Football  2017             37
# 1    Basketball  2017             11
# 2      Baseball  2017              9
# 3        Soccer  2017              7
# 4    Ice hockey  2017              4
# ..          ...   ...            ...
# 149   Wrestling  2004              1
# 150     Bowling  2004              0
# 151       Other  2004              4
# 152        None  2004             12
# 153  No opinion  2004              1
#
# [154 rows x 3 columns]

# %%
df2 = df_1.groupby(['Año','Sport'])[['Participantes']].sum().reset_index()
df2
# Out:
#       Año            Sport  Participantes
# 0    2004      Auto racing              5
# 1    2004         Baseball             10
# 2    2004       Basketball             13
# 3    2004          Bowling              0
# 4    2004           Boxing              1
# ..    ...              ...            ...
# 149  2017         Swimming              0
# 150  2017           Tennis              2
# 151  2017  Track and field              0
# 152  2017       Volleyball              1
# 153  2017        Wrestling              0
#
# [154 rows x 3 columns]

# %% [markdown]
# # Ordenamos solo los años de la columna presente.

# %%
años = sorted(df2['Año'].unique())

# %%
fig = px.scatter(df2, x='Año', y='Participantes',
                 size='Participantes',
                 color='Sport',
                 labels={'Sport': 'Deportes','Año':'Año' },
                 title='Deporte más popular en EEUU',)
fig.update_layout(showlegend=True, title_x=0.5)
fig.update_xaxes(tickvals= años)
fig.write_html("mi_grafica.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Se presenta el siguiente gráfico donde nos indica cual es el deporte que popular en EEUU, siendo el football el que lidera como deporte mas popular entre los años encuestados
